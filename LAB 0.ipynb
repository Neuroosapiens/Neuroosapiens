# %% [markdown]
# #  IMPORTING MATLAB DATASET

# %%
#Importing the cvs file using Pandas
import pandas as pd
#Importing Matplotlib to generate graphs
import matplotlib.pyplot as plt
# Setting up Data Frame from the cvs file
df = pd.read_csv(r'Lab0_data.csv')

# %% [markdown]
# ## Viewing Dataset

# %%
# View of the Data in the file 
df
# Out:
#      time_sec  VehicleSpeed_mph  EngineSpeed_rpm  EngineTorque  AccelPedalPos  \
# 0           0         23.838108      2321.373607    181.943925      19.978017
# 1           1         25.183644      1888.784906     63.500000      12.549024
# 2           2         25.592899      1932.336262     46.942052       5.007143
# 3           3         25.483396      1398.949090     -8.576612       0.000000
# 4           4         24.904355      1379.242030    -19.000000       0.000000
# ..        ...               ...              ...           ...            ...
# 826       826         15.377161      2109.273816     63.692830       9.019611
# 827       827         16.387776      1562.750000     38.330566       7.843140
# 828       828         16.879580      1607.067105     38.165314       7.450983
# 829       829         17.458570      1670.917720     71.562284      16.332432
# 830       830         19.819313      2010.301629    134.000000      19.607850
#
# ...

# %% [markdown]
# # INFORMATION OF DATASET

# %%
# Getting Information abiut the data in the file
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 831 entries, 0 to 830
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   time_sec          831 non-null    int64
#  1   VehicleSpeed_mph  831 non-null    float64
#  2   EngineSpeed_rpm   831 non-null    float64
#  3   EngineTorque      831 non-null    float64
#  4   AccelPedalPos     831 non-null    float64
#  5   BrakePedalPos     831 non-null    float64
#  6   TurnSignal        831 non-null    float64
#  7   Latitude_deg      830 non-null    float64
#  8   Longitude_deg     830 non-null    float64
#  9   Altitude          831 non-null    float64
#  10  Distance          830 non-null    float64
#  11  SteerAngle        831 non-null    float64
#  12  TransmissionGear  831 non-null    float64
#  13  SPaT_signal       831 non-null    int64
#  14  SPaT_dist         830 non-null    float64
# dtypes: float64(13), int64(2)
# memory usage: 97.5 KB

# %% [markdown]
# ## Description of dataset

# %%
# Dataset Desceiption
df.describe()
# Out:
#          time_sec  VehicleSpeed_mph  EngineSpeed_rpm  EngineTorque  \
# count  831.000000        831.000000       831.000000    831.000000
# mean   415.000000         17.403828      1225.693842     35.615563
# std    240.033331         15.554982       536.241905     59.877815
# min      0.000000          0.000000         0.000000    -48.500000
# 25%    207.500000          0.000000       704.017061     -0.421441
# 50%    415.000000         17.654800      1290.069869     12.496079
# 75%    622.500000         33.585920      1572.453660     70.000000
# max    830.000000         41.423561      2834.111279    238.149928
#
#        AccelPedalPos  BrakePedalPos  TurnSignal  Latitude_deg  Longitude_deg  \
# count     831.000000     831.000000  831.000000    830.000000     830.000000
# mean        6.071011       8.717998    0.447672     40.572132    -105.084745
# std         8.544509       9.400876    0.507937      0.005937       0.008233
# ...

# %% [markdown]
# ## Null value count

# %%
# Checking the number of null values
df.isna().sum()
# Out:
# time_sec            0
# VehicleSpeed_mph    0
# EngineSpeed_rpm     0
# EngineTorque        0
# AccelPedalPos       0
# BrakePedalPos       0
# TurnSignal          0
# Latitude_deg        1
# Longitude_deg       1
# Altitude            0
# Distance            1
# SteerAngle          0
# TransmissionGear    0
# SPaT_signal         0
# SPaT_dist           1
# dtype: int64

# %% [markdown]
# # GRAPHS OF DATA

# %% [markdown]
# ## Time Vs Vehicle Speed

# %%
# Setting up size of graph
plt.figure(figsize=(20, 11))
# Setting up the range and divisions in graph
plt.xticks(range(0, 850, 30))
# Displalying a grid in the background
plt.grid()
# Setting up the Width of the Data Line
plt.rcParams['lines.linewidth'] = 5
# Title of the Graph and Size of Text
plt.title('Time Vs Vehicle Speed', size=(50))
# Labeling and Size text Size of X axis
plt.xlabel('Time [s]', size=(25))
# Labeling and text size of the Y axis
plt.ylabel('Speed [mph]', size=(25))
# Plotting the Graph
plt.plot('time_sec', 'VehicleSpeed_mph', data=df)

# %% [markdown]
# ## Time Vs EngineSpeed

# %%
plt.figure(figsize=(20, 11))
plt.xticks(range(0, 850, 50))
plt.grid()
plt.rcParams['lines.linewidth'] = 3
plt.title('Time Vs Engine RPM', size=(50))
plt.xlabel('Time [s]', size=25)
plt.ylabel('Engine [RPM]', size=(25))
plt.plot('time_sec', 'EngineSpeed_rpm', data=df)

# %% [markdown]
# ## Time Vs Engine Torque

# %%
plt.figure(figsize=(20, 13))
plt.xticks(range(0, 840, 20))
plt.grid()
plt.rcParams['lines.linewidth'] = 2.5
plt.title('Time Vs Engine Torque', size=(50))
plt.xlabel('Time [s]', size=25)
plt.ylabel('Engine Torque [Nm]', size=(25))
plt.plot('time_sec', 'EngineTorque', data=df)

# %% [markdown]
# ## Time Vs Accleration Pedal Position

# %%
plt.figure(figsize=(20, 13))
plt.xticks(range(0, 850, 25))
plt.grid()
plt.rcParams['lines.linewidth'] = 2.5
plt.title('Time Vs Accel Pedal Pos', size=(50))
plt.xlabel('Time [s]', size=25)
plt.ylabel('Accel Pedal Pos', size=(25))
plt.plot('time_sec', 'AccelPedalPos', data=df)

# %% [markdown]
# ## Time Vs Break Pedal Position

# %%
plt.figure(figsize=(20, 13))
plt.xticks(range(0, 850, 100))
plt.grid()
plt.rcParams['lines.linewidth'] = 2
plt.title('Time Vs Brake Pedal Pos', size=(50))
plt.xlabel('Time [s]', size=25)
plt.ylabel('Brake Pedal Pos', size=(25))
plt.plot('time_sec', 'BrakePedalPos', data=df)

# %% [markdown]
# ## Time Vs Turn Signal

# %%
plt.figure(figsize=(20, 13))
plt.xticks(range(0, 850, 50))
plt.grid()
plt.rcParams['lines.linewidth'] = 3
plt.title('Time Vs Turn Signal', size=(50))
plt.xlabel('Time [s]', size=25)
plt.ylabel('Turn Signal', size=(25))
plt.plot('time_sec', 'TurnSignal', data=df)

# %% [markdown]
# ## Time Vs Latitude

# %%
plt.figure(figsize=(20, 13))
plt.xticks(range(0, 850, 50))
plt.grid()
plt.rcParams['lines.linewidth'] = 7
plt.title('Time Vs Latitude', size=(50))
plt.xlabel('Time [s]', size=25)
plt.ylabel('Latitude [deg]', size=(25))
plt.plot('time_sec', 'Latitude_deg', data=df)

# %% [markdown]
# ## Time Vs Longitude

# %%
plt.figure(figsize=(20, 13))
plt.xticks(range(0, 850, 50))
plt.grid()
plt.rcParams['lines.linewidth'] = 7
plt.title('Time Vs Longitude', size=(50))
plt.xlabel('Time [s]', size=25)
plt.ylabel('Longitude [deg]', size=(25))
plt.plot('time_sec', 'Longitude_deg', data=df)

# %% [markdown]
# ## Time Vs Altitude

# %%
plt.figure(figsize=(20, 11))
plt.xticks(range(0, 850, 50))
plt.grid()
plt.rcParams['lines.linewidth'] = 5
plt.title('Time Vs Altitude', size=(50))
plt.xlabel('Time [s]', size=(25))
plt.ylabel('Altitude [m]', size=(25))
plt.plot('time_sec', 'Altitude', data=df)

# %% [markdown]
# ## Time Vs Distance

# %%
plt.figure(figsize=(20, 11))
plt.xticks(range(0, 850, 50))
plt.grid()
plt.rcParams['lines.linewidth'] = 8
plt.title('Time Vs Distance', size=(50))
plt.xlabel('Time [s]', size=(25))
plt.ylabel('Distance [m]', size=(25))
plt.plot('time_sec', 'Distance', data=df)

# %% [markdown]
# ## Time Vs Steering Angle

# %%
plt.figure(figsize=(20, 11))
plt.xticks(range(0, 850, 50))
plt.grid()
plt.rcParams['lines.linewidth'] = 2
plt.title('Time Vs Steer Angle', size=(50))
plt.xlabel('Time [s]', size=(25))
plt.ylabel('Steer Angle [deg]', size=(25))
plt.plot('time_sec', 'SteerAngle', data=df)

# %%
plt.figure(figsize=(20, 11))
plt.xticks(range(0, 850, 50))
plt.grid()
plt.rcParams['lines.linewidth'] = 5
plt.title('Time Vs Transmission Gear', size=(50))
plt.xlabel('Time [s]', size=(25))
plt.ylabel('Transmission Gear', size=(25))
plt.plot('time_sec', 'TransmissionGear', data=df)

# %% [markdown]
# # TIME Vs SPaT SIGNAL

# %%
df_red = df[df.SPaT_signal == 1]

# %%
df_yellow = df[df.SPaT_signal == 2]

# %%
df_green = df[df.SPaT_signal == 3]

# %%
plt.figure(figsize=(20, 11))
plt.xticks(range(0, 850, 50))
plt.grid()
plt.rcParams['lines.linewidth'] = 5
plt.title('Time Vs SPaT_signal', size=(50))
plt.xlabel('Time [s]', size=(25))
plt.ylabel('SPaT_signal', size=(25))
plt.plot('time_sec', 'SPaT_signal', data=df_red, color = 'red')
plt.plot('time_sec', 'SPaT_signal', data=df_yellow, color = 'yellow')
plt.plot('time_sec', 'SPaT_signal', data=df_green, color = 'green')

# %% [markdown]
# ## Time Vs SPaT Signal

# %%
plt.figure(figsize=(20, 11))
plt.xticks(range(0, 850, 200))
plt.grid()
plt.rcParams['lines.linewidth'] = 3
plt.title('Time Vs SPaT_signal', size=(50))
plt.xlabel('Time [s]', size=(25))
plt.ylabel('SPaT_signal', size=(25))
plt.plot('time_sec', 'SPaT_signal', data=df)
plt.scatter('time_sec', 'SPaT_signal', data=df_red, color = 'red', linewidth = 7)
plt.scatter('time_sec', 'SPaT_signal', data=df_yellow, color = 'yellow', linewidth = 7)
plt.scatter('time_sec', 'SPaT_signal', data=df_green, color = 'green', linewidth = 7)

# %% [markdown]
# ## Time Vs SPaT Distance

# %%
plt.figure(figsize=(20, 11))
plt.xticks(range(0, 850, 50))
plt.grid()
plt.rcParams['lines.linewidth'] = 5
plt.title('Time Vs SPaT Distance', size=(50))
plt.xlabel('Time [s]', size=(25))
plt.ylabel('SPaT Dist [m]', size=(25))
plt.plot('time_sec', 'SPaT_dist', data=df)
